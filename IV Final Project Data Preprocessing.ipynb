# %%
import pandas as pd
import json

# %%
menu = pd.read_csv('menu.csv')

# %%
menu
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# ...

# %%
menu.drop(['Calories from Fat'],axis='columns',inplace=True)

# %%
menu
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
# ...

# %%
menu.drop(['Total Fat (% Daily Value)'],axis='columns',inplace=True)

# %%
menu.drop(['Saturated Fat'],axis='columns',inplace=True)

# %%
l = ['Saturated Fat (% Daily Value)','Trans Fat','Cholesterol','Cholesterol (% Daily Value)','Sodium (% Daily Value)','Carbohydrates (% Daily Value)','Dietary Fiber','Dietary Fiber (% Daily Value)','Vitamin A (% Daily Value)','Vitamin C (% Daily Value)','Calcium (% Daily Value)','Iron (% Daily Value)']

# %%
for i in l:
    menu.drop([i],axis='columns',inplace=True)

# %%
menu
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
# ...

# %%
menu.insert(0,'root',"McDonald\'s")

# %%
menu
# Out:
#            root            Category  \
# 0    McDonald's           Breakfast
# 1    McDonald's           Breakfast
# 2    McDonald's           Breakfast
# 3    McDonald's           Breakfast
# 4    McDonald's           Breakfast
# ..          ...                 ...
# 255  McDonald's  Smoothies & Shakes
# 256  McDonald's  Smoothies & Shakes
# 257  McDonald's  Smoothies & Shakes
# 258  McDonald's  Smoothies & Shakes
# 259  McDonald's  Smoothies & Shakes
#
#                                                   Item     Serving Size  \
# 0                                         Egg McMuffin   4.8 oz (136 g)
# 1                                    Egg White Delight   4.8 oz (135 g)
# 2                                     Sausage McMuffin   3.9 oz (111 g)
# 3                            Sausage McMuffin with Egg   5.7 oz (161 g)
# 4                     Sausage McMuffin with Egg Whites   5.7 oz (161 g)
# ..                                                 ...              ...
# ...

# %%
menu.insert(3,'ItemType',menu['Item'].apply(lambda x :x.split('(')[-1]))

# %%
menu
# Out:
#            root            Category  \
# 0    McDonald's           Breakfast
# 1    McDonald's           Breakfast
# 2    McDonald's           Breakfast
# 3    McDonald's           Breakfast
# 4    McDonald's           Breakfast
# ..          ...                 ...
# 255  McDonald's  Smoothies & Shakes
# 256  McDonald's  Smoothies & Shakes
# 257  McDonald's  Smoothies & Shakes
# 258  McDonald's  Smoothies & Shakes
# 259  McDonald's  Smoothies & Shakes
#
#                                                   Item  \
# 0                                         Egg McMuffin
# 1                                    Egg White Delight
# 2                                     Sausage McMuffin
# 3                            Sausage McMuffin with Egg
# 4                     Sausage McMuffin with Egg Whites
# ..                                                 ...
# 255                 McFlurry with Oreo Cookies (Small)
# 256                McFlurry with Oreo Cookies (Medium)
# ...

# %%
menu.insert(3,'DrawItem',menu['Item'].apply(lambda x :x.split('(')[0]))

# %%
menu
# Out:
#            root            Category  \
# 0    McDonald's           Breakfast
# 1    McDonald's           Breakfast
# 2    McDonald's           Breakfast
# 3    McDonald's           Breakfast
# 4    McDonald's           Breakfast
# ..          ...                 ...
# 255  McDonald's  Smoothies & Shakes
# 256  McDonald's  Smoothies & Shakes
# 257  McDonald's  Smoothies & Shakes
# 258  McDonald's  Smoothies & Shakes
# 259  McDonald's  Smoothies & Shakes
#
#                                                   Item  \
# 0                                         Egg McMuffin
# 1                                    Egg White Delight
# 2                                     Sausage McMuffin
# 3                            Sausage McMuffin with Egg
# 4                     Sausage McMuffin with Egg Whites
# ..                                                 ...
# 255                 McFlurry with Oreo Cookies (Small)
# 256                McFlurry with Oreo Cookies (Medium)
# ...

# %%
menu['ItemType'] = menu['ItemType'].apply(lambda x :x.split(')')[0])

# %%
menu
# Out:
#            root            Category  \
# 0    McDonald's           Breakfast
# 1    McDonald's           Breakfast
# 2    McDonald's           Breakfast
# 3    McDonald's           Breakfast
# 4    McDonald's           Breakfast
# ..          ...                 ...
# 255  McDonald's  Smoothies & Shakes
# 256  McDonald's  Smoothies & Shakes
# 257  McDonald's  Smoothies & Shakes
# 258  McDonald's  Smoothies & Shakes
# 259  McDonald's  Smoothies & Shakes
#
#                                                   Item  \
# 0                                         Egg McMuffin
# 1                                    Egg White Delight
# 2                                     Sausage McMuffin
# 3                            Sausage McMuffin with Egg
# 4                     Sausage McMuffin with Egg Whites
# ..                                                 ...
# 255                 McFlurry with Oreo Cookies (Small)
# 256                McFlurry with Oreo Cookies (Medium)
# ...

# %%
menu.loc[menu['DrawItem']==menu['ItemType'],'ItemType'] = ''

# %%
menu
# Out:
#            root            Category  \
# 0    McDonald's           Breakfast
# 1    McDonald's           Breakfast
# 2    McDonald's           Breakfast
# 3    McDonald's           Breakfast
# 4    McDonald's           Breakfast
# ..          ...                 ...
# 255  McDonald's  Smoothies & Shakes
# 256  McDonald's  Smoothies & Shakes
# 257  McDonald's  Smoothies & Shakes
# 258  McDonald's  Smoothies & Shakes
# 259  McDonald's  Smoothies & Shakes
#
#                                                   Item  \
# 0                                         Egg McMuffin
# 1                                    Egg White Delight
# 2                                     Sausage McMuffin
# 3                            Sausage McMuffin with Egg
# 4                     Sausage McMuffin with Egg Whites
# ..                                                 ...
# 255                 McFlurry with Oreo Cookies (Small)
# 256                McFlurry with Oreo Cookies (Medium)
# ...

# %%
menu['DrawItem'].value_counts()
# Out:
# Chicken McNuggets                          5
# Coca-Cola Classic                          4
# Iced Tea                                   4
# Diet Coke                                  4
# Sprite                                     4
#                                           ..
# Minute Maid 100% Apple Juice Box           1
# Bacon Cheddar McChicken                    1
# Filet-O-Fish                               1
# Premium Crispy Chicken Classic Sandwich    1
# Kids Ice Cream Cone                        1
# Name: DrawItem, Length: 140, dtype: int64

# %%
menu['DrawItem'].nunique()
# Out:
# 140

# %%
menu.rename(columns={'Item':'id'})
# Out:
#            root            Category  \
# 0    McDonald's           Breakfast
# 1    McDonald's           Breakfast
# 2    McDonald's           Breakfast
# 3    McDonald's           Breakfast
# 4    McDonald's           Breakfast
# ..          ...                 ...
# 255  McDonald's  Smoothies & Shakes
# 256  McDonald's  Smoothies & Shakes
# 257  McDonald's  Smoothies & Shakes
# 258  McDonald's  Smoothies & Shakes
# 259  McDonald's  Smoothies & Shakes
#
#                                                     id  \
# 0                                         Egg McMuffin
# 1                                    Egg White Delight
# 2                                     Sausage McMuffin
# 3                            Sausage McMuffin with Egg
# 4                     Sausage McMuffin with Egg Whites
# ..                                                 ...
# 255                 McFlurry with Oreo Cookies (Small)
# 256                McFlurry with Oreo Cookies (Medium)
# ...

# %%
menu['Serving Size'] = menu['Serving Size'].apply(lambda x :x.split(' ')[0])

# %%
menu
# Out:
#            root            Category  \
# 0    McDonald's           Breakfast
# 1    McDonald's           Breakfast
# 2    McDonald's           Breakfast
# 3    McDonald's           Breakfast
# 4    McDonald's           Breakfast
# ..          ...                 ...
# 255  McDonald's  Smoothies & Shakes
# 256  McDonald's  Smoothies & Shakes
# 257  McDonald's  Smoothies & Shakes
# 258  McDonald's  Smoothies & Shakes
# 259  McDonald's  Smoothies & Shakes
#
#                                                   Item  \
# 0                                         Egg McMuffin
# 1                                    Egg White Delight
# 2                                     Sausage McMuffin
# 3                            Sausage McMuffin with Egg
# 4                     Sausage McMuffin with Egg Whites
# ..                                                 ...
# 255                 McFlurry with Oreo Cookies (Small)
# 256                McFlurry with Oreo Cookies (Medium)
# ...

# %%
menu.rename(columns={'Item':'id'},inplace=True)

# %%
menu
# Out:
#            root            Category  \
# 0    McDonald's           Breakfast
# 1    McDonald's           Breakfast
# 2    McDonald's           Breakfast
# 3    McDonald's           Breakfast
# 4    McDonald's           Breakfast
# ..          ...                 ...
# 255  McDonald's  Smoothies & Shakes
# 256  McDonald's  Smoothies & Shakes
# 257  McDonald's  Smoothies & Shakes
# 258  McDonald's  Smoothies & Shakes
# 259  McDonald's  Smoothies & Shakes
#
#                                                     id  \
# 0                                         Egg McMuffin
# 1                                    Egg White Delight
# 2                                     Sausage McMuffin
# 3                            Sausage McMuffin with Egg
# 4                     Sausage McMuffin with Egg Whites
# ..                                                 ...
# 255                 McFlurry with Oreo Cookies (Small)
# 256                McFlurry with Oreo Cookies (Medium)
# ...

# %%
menu.to_csv('./output.csv',index=True,sep=',')

# %%
new=pd.DataFrame()

# %%
new
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
new['name'],new['parent'] = list(menu['Category']),list(menu['root'])

# %%
new
# Out:
#                    name      parent
# 0             Breakfast  McDonald's
# 1             Breakfast  McDonald's
# 2             Breakfast  McDonald's
# 3             Breakfast  McDonald's
# 4             Breakfast  McDonald's
# ..                  ...         ...
# 255  Smoothies & Shakes  McDonald's
# 256  Smoothies & Shakes  McDonald's
# 257  Smoothies & Shakes  McDonald's
# 258  Smoothies & Shakes  McDonald's
# 259  Smoothies & Shakes  McDonald's
#
# [260 rows x 2 columns]

# %%
new.insert(2,'value',0)

# %%
new
# Out:
#                    name      parent  value
# 0             Breakfast  McDonald's      0
# 1             Breakfast  McDonald's      0
# 2             Breakfast  McDonald's      0
# 3             Breakfast  McDonald's      0
# 4             Breakfast  McDonald's      0
# ..                  ...         ...    ...
# 255  Smoothies & Shakes  McDonald's      0
# 256  Smoothies & Shakes  McDonald's      0
# 257  Smoothies & Shakes  McDonald's      0
# 258  Smoothies & Shakes  McDonald's      0
# 259  Smoothies & Shakes  McDonald's      0
#
# [260 rows x 3 columns]

# %%
new1 = pd.DataFrame()

# %%
new1['name'] = list(menu['DrawItem'])
new1['parent'] = list(menu['Category'])
new1['value'] = list(menu['Serving Size'])
new1['check'] = list(menu['ItemType'])

# %%
new1.loc[new1['check']!='','value'] = '0'

# %%
new1.drop(['check'],axis='columns',inplace=True)

# %%
new1
# Out:
#                                           name              parent value
# 0                                 Egg McMuffin           Breakfast   4.8
# 1                            Egg White Delight           Breakfast   4.8
# 2                             Sausage McMuffin           Breakfast   3.9
# 3                    Sausage McMuffin with Egg           Breakfast   5.7
# 4             Sausage McMuffin with Egg Whites           Breakfast   5.7
# ..                                         ...                 ...   ...
# 255                McFlurry with Oreo Cookies   Smoothies & Shakes     0
# 256                McFlurry with Oreo Cookies   Smoothies & Shakes     0
# 257                McFlurry with Oreo Cookies   Smoothies & Shakes     0
# 258  McFlurry with Reese's Peanut Butter Cups   Smoothies & Shakes     0
# 259  McFlurry with Reese's Peanut Butter Cups   Smoothies & Shakes     0
#
# [260 rows x 3 columns]

# %%
new2 = pd.DataFrame()

# %%
new = new.append(new1,ignore_index=True)

# %%
new
# Out:
#                                           name              parent value
# 0                                    Breakfast          McDonald's     0
# 1                                    Breakfast          McDonald's     0
# 2                                    Breakfast          McDonald's     0
# 3                                    Breakfast          McDonald's     0
# 4                                    Breakfast          McDonald's     0
# ..                                         ...                 ...   ...
# 515                McFlurry with Oreo Cookies   Smoothies & Shakes     0
# 516                McFlurry with Oreo Cookies   Smoothies & Shakes     0
# 517                McFlurry with Oreo Cookies   Smoothies & Shakes     0
# 518  McFlurry with Reese's Peanut Butter Cups   Smoothies & Shakes     0
# 519  McFlurry with Reese's Peanut Butter Cups   Smoothies & Shakes     0
#
# [520 rows x 3 columns]

# %%
new2['name'] = list(menu['id'])
new2['parent'] = list(menu['DrawItem'])
new2['value'] = list(menu['Serving Size'])

# %%
new2
# Out:
#                                                   name  \
# 0                                         Egg McMuffin
# 1                                    Egg White Delight
# 2                                     Sausage McMuffin
# 3                            Sausage McMuffin with Egg
# 4                     Sausage McMuffin with Egg Whites
# ..                                                 ...
# 255                 McFlurry with Oreo Cookies (Small)
# 256                McFlurry with Oreo Cookies (Medium)
# 257                 McFlurry with Oreo Cookies (Snack)
# 258  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#                                         parent value
# 0                                 Egg McMuffin   4.8
# 1                            Egg White Delight   4.8
# 2                             Sausage McMuffin   3.9
# 3                    Sausage McMuffin with Egg   5.7
# ...

# %%
new2 = new2.drop(new2[new2.name == new2.parent].index)

# %%
new2
# Out:
#                                                   name  \
# 6        Bacon, Egg & Cheese Biscuit (Regular Biscuit)
# 7          Bacon, Egg & Cheese Biscuit (Large Biscuit)
# 8    Bacon, Egg & Cheese Biscuit with Egg Whites (R...
# 9    Bacon, Egg & Cheese Biscuit with Egg Whites (L...
# 10                   Sausage Biscuit (Regular Biscuit)
# ..                                                 ...
# 255                 McFlurry with Oreo Cookies (Small)
# 256                McFlurry with Oreo Cookies (Medium)
# 257                 McFlurry with Oreo Cookies (Snack)
# 258  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#                                            parent value
# 6                    Bacon, Egg & Cheese Biscuit    5.3
# 7                    Bacon, Egg & Cheese Biscuit    5.8
# 8    Bacon, Egg & Cheese Biscuit with Egg Whites    5.4
# 9    Bacon, Egg & Cheese Biscuit with Egg Whites    5.9
# ...

# %%
new = new.append(new2,ignore_index=True)

# %%
new
# Out:
#                                                   name  \
# 0                                            Breakfast
# 1                                            Breakfast
# 2                                            Breakfast
# 3                                            Breakfast
# 4                                            Breakfast
# ..                                                 ...
# 703                 McFlurry with Oreo Cookies (Small)
# 704                McFlurry with Oreo Cookies (Medium)
# 705                 McFlurry with Oreo Cookies (Snack)
# 706  McFlurry with Reese's Peanut Butter Cups (Medium)
# 707   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#                                         parent value
# 0                                   McDonald's     0
# 1                                   McDonald's     0
# 2                                   McDonald's     0
# 3                                   McDonald's     0
# ...

# %%
new = new.drop_duplicates(keep='first')

# %%
new
# Out:
#                                                   name  \
# 0                                            Breakfast
# 42                                         Beef & Pork
# 57                                      Chicken & Fish
# 84                                              Salads
# 90                                      Snacks & Sides
# ..                                                 ...
# 703                 McFlurry with Oreo Cookies (Small)
# 704                McFlurry with Oreo Cookies (Medium)
# 705                 McFlurry with Oreo Cookies (Snack)
# 706  McFlurry with Reese's Peanut Butter Cups (Medium)
# 707   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#                                         parent value
# 0                                   McDonald's     0
# 42                                  McDonald's     0
# 57                                  McDonald's     0
# 84                                  McDonald's     0
# ...

# %%
new = new.reset_index(drop=True)

# %%
new
# Out:
#                                                   name  \
# 0                                            Breakfast
# 1                                          Beef & Pork
# 2                                       Chicken & Fish
# 3                                               Salads
# 4                                       Snacks & Sides
# ..                                                 ...
# 332                 McFlurry with Oreo Cookies (Small)
# 333                McFlurry with Oreo Cookies (Medium)
# 334                 McFlurry with Oreo Cookies (Snack)
# 335  McFlurry with Reese's Peanut Butter Cups (Medium)
# 336   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#                                         parent value
# 0                                   McDonald's     0
# 1                                   McDonald's     0
# 2                                   McDonald's     0
# 3                                   McDonald's     0
# ...

# %%
new
# Out:
#                                                   name  \
# 0                                            Breakfast
# 1                                          Beef & Pork
# 2                                       Chicken & Fish
# 3                                               Salads
# 4                                       Snacks & Sides
# ..                                                 ...
# 332                 McFlurry with Oreo Cookies (Small)
# 333                McFlurry with Oreo Cookies (Medium)
# 334                 McFlurry with Oreo Cookies (Snack)
# 335  McFlurry with Reese's Peanut Butter Cups (Medium)
# 336   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#                                         parent value
# 0                                   McDonald's     0
# 1                                   McDonald's     0
# 2                                   McDonald's     0
# 3                                   McDonald's     0
# ...

# %%
last = pd.DataFrame({'name':"McDonald\'s", 'parent':'','value':0},index=[1])

# %%
last
# Out:
#          name parent  value
# 1  McDonald's             0

# %%
new = new.append(last,ignore_index=True)

# %%
new
# Out:
#                                                   name  \
# 0                                            Breakfast
# 1                                          Beef & Pork
# 2                                       Chicken & Fish
# 3                                               Salads
# 4                                       Snacks & Sides
# ..                                                 ...
# 333                McFlurry with Oreo Cookies (Medium)
# 334                 McFlurry with Oreo Cookies (Snack)
# 335  McFlurry with Reese's Peanut Butter Cups (Medium)
# 336   McFlurry with Reese's Peanut Butter Cups (Snack)
# 337                                         McDonald's
#
#                                         parent value
# 0                                   McDonald's     0
# 1                                   McDonald's     0
# 2                                   McDonald's     0
# 3                                   McDonald's     0
# ...

# %%
new.to_csv('./ForTreeMap_full_name.csv',index=False,sep=',')
